# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
not_hot_100 = pd.read_csv("not_hot.csv")

# %%
not_hot_100
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 0         1                          1                        8
# 1         2                          2                        3
# 2         3                          1                       11
# 3         4                          3                        5
# 4         5                          5                        1
# ...     ...                        ...                      ...
# 1551   1552                        195                        1
# 1552   1553                        196                        1
# 1553   1554                        197                        1
# 1554   1555                        198                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting                           Song Name     Streams  \
# 0      2021-07-23--2021-07-30                             Beggin'  48,633,449
# ...

# %%
not_hot_100 = nothot100[["Artist","Song Name"]]

# %%
not_hot_100
# Out:
#                              Artist                           Song Name
# 0                          Måneskin                             Beggin'
# 1                     The Kid LAROI           STAY (with Justin Bieber)
# 2                    Olivia Rodrigo                            good 4 u
# 3                        Ed Sheeran                          Bad Habits
# 4                         Lil Nas X   INDUSTRY BABY (feat. Jack Harlow)
# ...                             ...                                 ...
# 1551                       Dua Lipa                           New Rules
# 1552                 Jorge & Mateus                  Cheirosa - Ao Vivo
# 1553                 Camila Cabello           Havana (feat. Young Thug)
# 1554  Dadá Boladão, Tati Zaqui, OIK          Surtada - Remix Brega Funk
# 1555                   Taylor Swift  Lover (Remix) [feat. Shawn Mendes]
#
# [1556 rows x 2 columns]

# %%
hot_100 = pd.read_csv("billboard_top_100.csv")

# %%
hot_100
# Out:
#                Song                         Artist
# 0           Vampire                 Olivia Rodrigo
# 1        Last Night                  Morgan Wallen
# 2          Fast Car                     Luke Combs
# 3         Calm Down            Rema & Selena Gomez
# 4           Flowers                    Miley Cyrus
# ..              ...                            ...
# 95  Ain't That Some                  Morgan Wallen
# 96          Lagunas      Peso Pluma & Jasiel Nunez
# 97       Dial Drunk                     Noah Kahan
# 98          Save Me  Jelly Roll With Lainey Wilson
# 99            Jaded                    Miley Cyrus
#
# [100 rows x 2 columns]

# %%
not_hot_100 = not_hot_100.rename(columns={'Artist Name': 'Artist', 'Song Name': 'Song'})

# %%
not_hot_100 = not_hot_100[['Song', 'Artist']]

# %%
not_hot_100
# Out:
#                                     Song                         Artist
# 0                                Beggin'                       Måneskin
# 1              STAY (with Justin Bieber)                  The Kid LAROI
# 2                               good 4 u                 Olivia Rodrigo
# 3                             Bad Habits                     Ed Sheeran
# 4      INDUSTRY BABY (feat. Jack Harlow)                      Lil Nas X
# ...                                  ...                            ...
# 1551                           New Rules                       Dua Lipa
# 1552                  Cheirosa - Ao Vivo                 Jorge & Mateus
# 1553           Havana (feat. Young Thug)                 Camila Cabello
# 1554          Surtada - Remix Brega Funk  Dadá Boladão, Tati Zaqui, OIK
# 1555  Lover (Remix) [feat. Shawn Mendes]                   Taylor Swift
#
# [1556 rows x 2 columns]

# %%
concatenated_df = pd.concat([hot_100, not_hot_100]).drop_duplicates()

# %%
concatenated_df
# Out:
#                                     Song                         Artist
# 0                                Vampire                 Olivia Rodrigo
# 1                             Last Night                  Morgan Wallen
# 2                               Fast Car                     Luke Combs
# 3                              Calm Down            Rema & Selena Gomez
# 4                                Flowers                    Miley Cyrus
# ...                                  ...                            ...
# 1551                           New Rules                       Dua Lipa
# 1552                  Cheirosa - Ao Vivo                 Jorge & Mateus
# 1553           Havana (feat. Young Thug)                 Camila Cabello
# 1554          Surtada - Remix Brega Funk  Dadá Boladão, Tati Zaqui, OIK
# 1555  Lover (Remix) [feat. Shawn Mendes]                   Taylor Swift
#
# [1656 rows x 2 columns]

# %%
not_hot_100.to_csv('not_hot_100_cleaned.csv', index=False)
